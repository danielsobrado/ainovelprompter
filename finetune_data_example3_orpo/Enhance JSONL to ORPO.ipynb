# %%
import csv
import json
import random
from openai import OpenAI
import re
from html import unescape

# %%
def generate_rejected_response(client, prompt, temperature, seed):
    completion = client.chat.completions.create(
        model="professorf/Meta-Llama-3-8B-Instruct-16f-gguf/llama-3-8b-instruct-16f.gguf",
        messages=[
            {
                "role": "system",
                "content": "You are an expert novelist. Paraphrase the given text in your own words, refining the prose and making it a bit richer. Keep a similar length in your output to the original, not more than 50% difference, and shouldn't be shorter than the original text, only a bit more purple prose. Don't add additional text or notes to the output."
            },
            {
                "role": "user",
                "content": "Don't write additional story content or change the meaning, keep the original meaning and form. The response should contain only one paragraph. Rephrase the following text: " + prompt
            }
        ],
        temperature=temperature,
        seed=seed,
    )
    return completion.choices[0].message.content.strip()

# %%
def process_jsonl_file(input_file_path, output_file_path, client):
    total_lines = 0
    written_lines = 0
    skipped_lines = []
    total_retries = 0

    with open(input_file_path, 'r', encoding='utf-8') as input_file:
        try:
            with open(output_file_path, 'r', encoding='utf-8') as output_file:
                csv_reader = csv.reader(output_file)
                written_lines = sum(1 for _ in csv_reader) - 1 
        except FileNotFoundError:
            pass

        start_line_number = written_lines + 1

        csv_writer = None
        output_file = None

        for line_number, line in enumerate(input_file, start=start_line_number):
            total_lines += 1

            if csv_writer is None:
                output_file = open(output_file_path, 'a', newline='', encoding='utf-8')
                csv_writer = csv.writer(output_file)
                if written_lines == 0:
                    csv_writer.writerow(['prompt', 'chosen', 'rejected'])

            json_data = json.loads(line)
            prompt = json_data['text'].split('\n<bot>: ')[0].replace('<human>: Rephrase the following text in the style of George MacDonald: ', '')
            chosen = json_data['text'].split('\n<bot>: ')[1]

            retry_count = 0
            while retry_count < 5:
                seed = random.randint(0, 2**32 - 1)
                temperature = round(random.uniform(0.7, 1.0), 1)

                rejected = generate_rejected_response(client, prompt, temperature, seed)

                if "###" in rejected:
                    failure_reason = "Response contains '###'"
                elif len(rejected.split('\n\n')) > 1:
                    failure_reason = "Response contains multiple paragraphs"
                elif len(rejected.split()) < int(0.85 * len(prompt.split())):
                    failure_reason = "Response is less than 85% the size of the input"
                elif len(rejected.split()) > int(2.5 * len(prompt.split())):
                    failure_reason = "Response is more than 2.5 times the length of the input"
                else:
                    break

                retry_count += 1
                total_retries += 1

            if retry_count == 5:
                print(f"Skipping line {line_number} after 5 retries: {prompt}")
                skipped_lines.append((line_number, failure_reason))
                continue

            csv_writer.writerow([prompt, chosen, rejected])
            written_lines += 1

            if written_lines % 100 == 0:
                output_file.flush()
                print(f"Progress saved at line {line_number}")
                print(f"Written lines: {written_lines}")
                print(f"Skipped lines: {len(skipped_lines)}")
                print(f"Total retries: {total_retries}")
                print()

        if output_file is not None:
            output_file.close()

    print("Summary:")
    print(f"Total lines: {total_lines}")
    print(f"Written lines: {written_lines}")
    print(f"Skipped lines: {len(skipped_lines)}")
    print(f"Total retries: {total_retries}")
    print("Skipped line details:")
    for line_number, reason in skipped_lines:
        print(f"Line {line_number}: {reason}")

# %%
# Set up the OpenAI client
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

# Specify the input and output file paths
input_file_path = 'G:\\texts\\train_data_book1_Drusniel_Meta-Llama-3-8B-Instruct-Q8_0.jsonl'
output_file_path = 'G:\\texts\\orpo_data_book1_Drusniel_Meta-Llama-3-8B-Instruct-Q8_0.csv'

# Process the JSONL file and generate the CSV file
process_jsonl_file(input_file_path, output_file_path, client)
# Out:
# Progress saved at line 3600
# Written lines: 3600
# Skipped lines: 0
# Total retries: 0
#
# Progress saved at line 3700
# Written lines: 3700
# Skipped lines: 0
# Total retries: 0
#
# Progress saved at line 3800
# Written lines: 3800
# Skipped lines: 0
# Total retries: 5
#
# Progress saved at line 3900
# Written lines: 3900
# Skipped lines: 0
# Total retries: 5
#
# Skipping line 3940 after 5 retries: "With an enigmatic glint in his eye, Kelsier whispered, 'The secrets I hold would lose their allure if revealed to you.'"
# Progress saved at line 4001
# Written lines: 4000
# Skipped lines: 1
# Total retries: 10
#
# Skipping line 4071 after 5 retries: "With a hint of resignation, Kelsier nodded in understanding," he spent twelve long months within those oppressive walls."
# Progress saved at line 4102
# Written lines: 4100
# Skipped lines: 2
# Total retries: 15
#
# Progress saved at line 4202
# Written lines: 4200
# Skipped lines: 2
# Total retries: 17
#
# Progress saved at line 4302
# Written lines: 4300
# Skipped lines: 2
# Total retries: 17
#
# Progress saved at line 4402
# Written lines: 4400
# Skipped lines: 2
# Total retries: 22
#
# Progress saved at line 4502
# Written lines: 4500
# Skipped lines: 2
# Total retries: 25
#
# Skipping line 4524 after 5 retries: "Ah, come along," he coaxed, beckoning her with a reassuring smile. "All's well that ends in laughter and good company, my dear."
# Progress saved at line 4603
# Written lines: 4600
# Skipped lines: 3
# Total retries: 30
#
# Skipping line 4671 after 5 retries: "As I pondered the notion, a sudden epiphany dawned on me - I had never previously considered the intricacies of this concept."
# Progress saved at line 4704
# Written lines: 4700
# Skipped lines: 4
# Total retries: 39
#
# Progress saved at line 4804
# Written lines: 4800
# Skipped lines: 4
# Total retries: 48
#
# Progress saved at line 4904
# Written lines: 4900
# Skipped lines: 4
# Total retries: 50
#
# Progress saved at line 5004
# Written lines: 5000
# Skipped lines: 4
# Total retries: 57
#
# Progress saved at line 5104
# Written lines: 5100
# Skipped lines: 4
# Total retries: 60
#
# Progress saved at line 5204
# Written lines: 5200
# Skipped lines: 4
# Total retries: 64
#
# Progress saved at line 5304
# Written lines: 5300
# Skipped lines: 4
# Total retries: 64
#
# Progress saved at line 5404
# Written lines: 5400
# Skipped lines: 4
# Total retries: 68
#
# Progress saved at line 5504
# Written lines: 5500
# Skipped lines: 4
# Total retries: 71
#
# Progress saved at line 5604
# Written lines: 5600
# Skipped lines: 4
# Total retries: 74
#
# Progress saved at line 5704
# Written lines: 5700
# Skipped lines: 4
# Total retries: 76
#
# Progress saved at line 5804
# Written lines: 5800
# Skipped lines: 4
# Total retries: 79
#
# Progress saved at line 5904
# Written lines: 5900
# Skipped lines: 4
# Total retries: 79
#
# Progress saved at line 6004
# Written lines: 6000
# Skipped lines: 4
# Total retries: 80
#
# Progress saved at line 6104
# Written lines: 6100
# Skipped lines: 4
# Total retries: 81
#
# Progress saved at line 6204
# Written lines: 6200
# Skipped lines: 4
# Total retries: 88
#
# Progress saved at line 6304
# Written lines: 6300
# Skipped lines: 4
# Total retries: 89
#
# Progress saved at line 6404
# Written lines: 6400
# Skipped lines: 4
# Total retries: 91
#
# Progress saved at line 6504
# Written lines: 6500
# Skipped lines: 4
# Total retries: 94
#
# Progress saved at line 6604
# Written lines: 6600
# Skipped lines: 4
# Total retries: 94
#
# Progress saved at line 6704
# Written lines: 6700
# Skipped lines: 4
# Total retries: 99
#
# Progress saved at line 6804
# Written lines: 6800
# Skipped lines: 4
# Total retries: 99
#
# Skipping line 6840 after 5 retries: "What are your words trying to convey, fair mistress?" the stalwart steward inquired, his stance a silent sentinel, positioned discreetly at her right flank.
# Progress saved at line 6905
# Written lines: 6900
# Skipped lines: 5
# Total retries: 104
#
# Progress saved at line 7005
# Written lines: 7000
# Skipped lines: 5
# Total retries: 105
#
# Progress saved at line 7105
# Written lines: 7100
# Skipped lines: 5
# Total retries: 112
#
# Progress saved at line 7205
# Written lines: 7200
# Skipped lines: 5
# Total retries: 112
#
# Progress saved at line 7305
# Written lines: 7300
# Skipped lines: 5
# Total retries: 113
#
# Progress saved at line 7405
# Written lines: 7400
# Skipped lines: 5
# Total retries: 113
#
# Progress saved at line 7505
# Written lines: 7500
# Skipped lines: 5
# Total retries: 113
#
# Progress saved at line 7605
# Written lines: 7600
# Skipped lines: 5
# Total retries: 114
#
# Progress saved at line 7705
# Written lines: 7700
# Skipped lines: 5
# Total retries: 114
#
# Progress saved at line 7805
# Written lines: 7800
# Skipped lines: 5
# Total retries: 115
#
# Progress saved at line 7905
# Written lines: 7900
# Skipped lines: 5
# Total retries: 115
#
# Progress saved at line 8005
# Written lines: 8000
# Skipped lines: 5
# Total retries: 115
#
# Progress saved at line 8105
# Written lines: 8100
# Skipped lines: 5
# Total retries: 118
#
# Progress saved at line 8205
# Written lines: 8200
# Skipped lines: 5
# Total retries: 118
#
# Progress saved at line 8305
# Written lines: 8300
# Skipped lines: 5
# Total retries: 119
#
# Progress saved at line 8405
# Written lines: 8400
# Skipped lines: 5
# Total retries: 119
#
# Progress saved at line 8505
# Written lines: 8500
# Skipped lines: 5
# Total retries: 121
#
# Progress saved at line 8605
# Written lines: 8600
# Skipped lines: 5
# Total retries: 121
#
# Progress saved at line 8705
# Written lines: 8700
# Skipped lines: 5
# Total retries: 122
#
# Progress saved at line 8805
# Written lines: 8800
# Skipped lines: 5
# Total retries: 124
#
# Progress saved at line 8905
# Written lines: 8900
# Skipped lines: 5
# Total retries: 129
#
# Progress saved at line 9005
# Written lines: 9000
# Skipped lines: 5
# Total retries: 129
#
# Progress saved at line 9105
# Written lines: 9100
# Skipped lines: 5
# Total retries: 129
#
# Progress saved at line 9205
# Written lines: 9200
# Skipped lines: 5
# Total retries: 130
#
# Progress saved at line 9305
# Written lines: 9300
# Skipped lines: 5
# Total retries: 130
#
# Progress saved at line 9405
# Written lines: 9400
# Skipped lines: 5
# Total retries: 132
#
# Progress saved at line 9505
# Written lines: 9500
# Skipped lines: 5
# Total retries: 134
#
# Progress saved at line 9605
# Written lines: 9600
# Skipped lines: 5
# Total retries: 134
#
# Progress saved at line 9705
# Written lines: 9700
# Skipped lines: 5
# Total retries: 137
#
# Progress saved at line 9805
# Written lines: 9800
# Skipped lines: 5
# Total retries: 137
#
# Progress saved at line 9905
# Written lines: 9900
# Skipped lines: 5
# Total retries: 139
#
# Progress saved at line 10005
# Written lines: 10000
# Skipped lines: 5
# Total retries: 141
#
# Progress saved at line 10105
# Written lines: 10100
# Skipped lines: 5
# Total retries: 141
#
# Progress saved at line 10205
# Written lines: 10200
# Skipped lines: 5
# Total retries: 148
#
# Progress saved at line 10305
# Written lines: 10300
# Skipped lines: 5
# Total retries: 148
#
# Progress saved at line 10405
# Written lines: 10400
# Skipped lines: 5
# Total retries: 150
#
# Progress saved at line 10505
# Written lines: 10500
# Skipped lines: 5
# Total retries: 151
#
# Progress saved at line 10605
# Written lines: 10600
# Skipped lines: 5
# Total retries: 151
#
# Progress saved at line 10705
# Written lines: 10700
# Skipped lines: 5
# Total retries: 153
#
# Progress saved at line 10805
# Written lines: 10800
# Skipped lines: 5
# Total retries: 154
#
# Progress saved at line 10905
# Written lines: 10900
# Skipped lines: 5
# Total retries: 160
#
# Progress saved at line 11005
# Written lines: 11000
# Skipped lines: 5
# Total retries: 160
#
# Progress saved at line 11105
# Written lines: 11100
# Skipped lines: 5
# Total retries: 160
#
# Progress saved at line 11205
# Written lines: 11200
# Skipped lines: 5
# Total retries: 162
#
# Progress saved at line 11305
# Written lines: 11300
# Skipped lines: 5
# Total retries: 162
#
# Progress saved at line 11405
# Written lines: 11400
# Skipped lines: 5
# Total retries: 167
#
# Progress saved at line 11505
# Written lines: 11500
# Skipped lines: 5
# Total retries: 168
#
# Progress saved at line 11605
# Written lines: 11600
# Skipped lines: 5
# Total retries: 168
#
# Progress saved at line 11705
# Written lines: 11700
# Skipped lines: 5
# Total retries: 168
#
# Progress saved at line 11805
# Written lines: 11800
# Skipped lines: 5
# Total retries: 168
#
# Skipping line 11841 after 5 retries: Unless this is some ingenious ruse, I am left to ponder the enigmatic nature of these proceedings. But, then again...
# Progress saved at line 11906
# Written lines: 11900
# Skipped lines: 6
# Total retries: 173
#
# Progress saved at line 12006
# Written lines: 12000
# Skipped lines: 6
# Total retries: 174
#
# Skipping line 12055 after 5 retries: "A challenge, I shall answer!" Sazed's mighty cry thundered forth, its resonant tone surprising even himself with its unanticipated depth and ferocity.
# Progress saved at line 12107
# Written lines: 12100
# Skipped lines: 7
# Total retries: 182
#
# Progress saved at line 12207
# Written lines: 12200
# Skipped lines: 7
# Total retries: 182
#
# Progress saved at line 12307
# Written lines: 12300
# Skipped lines: 7
# Total retries: 184
#
# Skipping line 12391 after 5 retries: "With royal presence as her constant companion, she served as a noble attendant within the very walls of the monarch's esteemed court."
# Progress saved at line 12408
# Written lines: 12400
# Skipped lines: 8
# Total retries: 189
#
# Progress saved at line 12508
# Written lines: 12500
# Skipped lines: 8
# Total retries: 190
#
# Progress saved at line 12608
# Written lines: 12600
# Skipped lines: 8
# Total retries: 190
#
# Progress saved at line 12708
# Written lines: 12700
# Skipped lines: 8
# Total retries: 190
#
# Progress saved at line 12808
# Written lines: 12800
# Skipped lines: 8
# Total retries: 191
#
# Progress saved at line 12908
# Written lines: 12900
# Skipped lines: 8
# Total retries: 191
#
# Progress saved at line 13008
# Written lines: 13000
# Skipped lines: 8
# Total retries: 191
#
# Progress saved at line 13108
# Written lines: 13100
# Skipped lines: 8
# Total retries: 193
#
# Progress saved at line 13208
# Written lines: 13200
# Skipped lines: 8
# Total retries: 195
#
# Progress saved at line 13308
# Written lines: 13300
# Skipped lines: 8
# Total retries: 196
#
# Progress saved at line 13408
# Written lines: 13400
# Skipped lines: 8
# Total retries: 197
#
# Progress saved at line 13508
# Written lines: 13500
# Skipped lines: 8
# Total retries: 197
#
# Progress saved at line 13608
# Written lines: 13600
# Skipped lines: 8
# Total retries: 197
#
# Progress saved at line 13708
# Written lines: 13700
# Skipped lines: 8
# Total retries: 197
#
# Progress saved at line 13808
# Written lines: 13800
# Skipped lines: 8
# Total retries: 197
#
# Progress saved at line 13908
# Written lines: 13900
# Skipped lines: 8
# Total retries: 199
#
# Progress saved at line 14008
# Written lines: 14000
# Skipped lines: 8
# Total retries: 200
#
# Progress saved at line 14108
# Written lines: 14100
# Skipped lines: 8
# Total retries: 201
#
# Progress saved at line 14208
# Written lines: 14200
# Skipped lines: 8
# Total retries: 205
#
# Progress saved at line 14308
# Written lines: 14300
# Skipped lines: 8
# Total retries: 206
#
# Progress saved at line 14408
# Written lines: 14400
# Skipped lines: 8
# Total retries: 210
#
# Progress saved at line 14508
# Written lines: 14500
# Skipped lines: 8
# Total retries: 211
#
# Progress saved at line 14608
# Written lines: 14600
# Skipped lines: 8
# Total retries: 213
#
# Progress saved at line 14708
# Written lines: 14700
# Skipped lines: 8
# Total retries: 214
#
# Progress saved at line 14808
# Written lines: 14800
# Skipped lines: 8
# Total retries: 215
#
# Progress saved at line 14908
# Written lines: 14900
# Skipped lines: 8
# Total retries: 215
#
# Progress saved at line 15008
# Written lines: 15000
# Skipped lines: 8
# Total retries: 215
#
# Progress saved at line 15108
# Written lines: 15100
# Skipped lines: 8
# Total retries: 215
#
# Progress saved at line 15208
# Written lines: 15200
# Skipped lines: 8
# Total retries: 216
#
# Progress saved at line 15308
# Written lines: 15300
# Skipped lines: 8
# Total retries: 220
#
# Progress saved at line 15408
# Written lines: 15400
# Skipped lines: 8
# Total retries: 220
#
# Progress saved at line 15508
# Written lines: 15500
# Skipped lines: 8
# Total retries: 222
#
# Progress saved at line 15608
# Written lines: 15600
# Skipped lines: 8
# Total retries: 224
#
# Progress saved at line 15708
# Written lines: 15700
# Skipped lines: 8
# Total retries: 224
#
# Progress saved at line 15808
# Written lines: 15800
# Skipped lines: 8
# Total retries: 224
#
# Progress saved at line 15908
# Written lines: 15900
# Skipped lines: 8
# Total retries: 224
#
# Progress saved at line 16008
# Written lines: 16000
# Skipped lines: 8
# Total retries: 226
#
# Progress saved at line 16108
# Written lines: 16100
# Skipped lines: 8
# Total retries: 229
#
# Progress saved at line 16208
# Written lines: 16200
# Skipped lines: 8
# Total retries: 230
#
# Progress saved at line 16308
# Written lines: 16300
# Skipped lines: 8
# Total retries: 231
#
# Progress saved at line 16408
# Written lines: 16400
# Skipped lines: 8
# Total retries: 232
#
# Progress saved at line 16508
# Written lines: 16500
# Skipped lines: 8
# Total retries: 232
#
# Progress saved at line 16608
# Written lines: 16600
# Skipped lines: 8
# Total retries: 233
#
# Progress saved at line 16708
# Written lines: 16700
# Skipped lines: 8
# Total retries: 233
#
# Progress saved at line 16808
# Written lines: 16800
# Skipped lines: 8
# Total retries: 233
#
# Progress saved at line 16908
# Written lines: 16900
# Skipped lines: 8
# Total retries: 234
#
# Summary:
# Total lines: 13429
# Written lines: 16998
# Skipped lines: 8
# Total retries: 235
# Skipped line details:
# Line 3940: Response is more than 2.5 times the length of the input
# Line 4071: Response is more than 2.5 times the length of the input
# Line 4524: Response is more than 2.5 times the length of the input
# Line 4671: Response is more than 2.5 times the length of the input
# Line 6840: Response is more than 2.5 times the length of the input
# Line 11841: Response is more than 2.5 times the length of the input
# Line 12055: Response is more than 2.5 times the length of the input
# Line 12391: Response is more than 2.5 times the length of the input

# %%
def normalize_dialogue(dialogue):
    # Normalize curly quotes to straight quotes
    dialogue = re.sub(r'[“”]', '"', dialogue)
    dialogue = re.sub(r'[‘’]', "'", dialogue)
    dialogue = re.sub(r'["""]', '"', dialogue)
    dialogue = re.sub(r'[""]', "'", dialogue)
    dialogue = re.sub(r"[''']", "'", dialogue)
    
    # Normalize ellipses
    dialogue = dialogue.replace('…', '...')
    
    # Normalize dashes
    dialogue = re.sub(r'[–—]', '-', dialogue)
    
    # Unescape HTML entities if necessary
    dialogue = unescape(dialogue)
    
    return dialogue

def normalize_file(input_file_path, output_file_path):
    try:
        with open(input_file_path, 'r', encoding='utf-8') as infile, \
             open(output_file_path, 'w', encoding='utf-8', newline='') as outfile:
            
            reader = csv.reader(infile)
            writer = csv.writer(outfile)
            
            for row in reader:
                normalized_row = [normalize_dialogue(field) for field in row]
                writer.writerow(normalized_row)
    
    except FileNotFoundError:
        print(f"File not found: {input_file_path}")
    
    except IOError:
        print(f"Error accessing file: {input_file_path}")

# %%
input_file_path = 'G:\\texts\\orpo_data_book1_Drusniel_Meta-Llama-3-8B-Instruct-Q8_0.csv'
output_file_path = 'G:\\texts\\orpo_train_data_normalized.csv'
normalize_file(input_file_path, output_file_path)

# %%
import csv
import json

def convert_to_json_format(input_file_path, output_file_path):
    try:
        with open(input_file_path, 'r', encoding='utf-8') as infile, \
             open(output_file_path, 'w', encoding='utf-8') as outfile:
            
            reader = csv.DictReader(infile)
            data = []
            
            for row in reader:
                instruction = f"Rephrase the following text in the style of Drusniel: {row['prompt']}"
                chosen = row['chosen']
                rejected = row['rejected']
                
                entry = {
                    "instruction": instruction,
                    "input": "",
                    "chosen": chosen,
                    "rejected": rejected
                }
                
                data.append(entry)
            
            json.dump(data, outfile, indent=2)
    
    except FileNotFoundError:
        print(f"File not found: {input_file_path}")
    
    except IOError:
        print(f"Error accessing file: {input_file_path}")

# %%
input_file_path = 'G:\\texts\\orpo_train_data_normalized.csv'
output_file_path = 'G:\\texts\\orpo_train_data_normalized.json'
convert_to_json_format(input_file_path, output_file_path)
